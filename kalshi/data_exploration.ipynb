# %%
import pandas as pd

# %%
from kalshi.events import Events

events = Events()
events = events.get_events(all_pages=False)
events_df = pd.DataFrame(events)
display(events_df.head())
# Out:
#    available_on_brokers                category collateral_return_type  \
# 0                  True                   World
# 1                  True                   World                 MECNET
# 2                  True     Climate and Weather
# 3                  True  Science and Technology
# 4                  True     Climate and Weather
#
#      event_ticker              last_updated_ts  mutually_exclusive  \
# 0   KXELONMARS-99  2026-02-26T08:50:31.901806Z               False
# 1    KXNEWPOPE-70  2026-02-26T08:50:31.901806Z                True
# 2    KXWARMING-50  2026-02-26T08:50:31.901806Z               False
# 3  KXMARSVRAIL-50  2026-02-26T08:50:31.901806Z               False
# 4  KXERUPTSUPER-0  2026-02-26T08:50:31.901806Z               False
#
#   series_ticker strike_period       sub_title  \
# 0    KXELONMARS                   Before 2099
# 1     KXNEWPOPE                   Before 2070
# 2     KXWARMING                   Before 2050
# 3   KXMARSVRAIL                   Before 2050
# 4  KXERUPTSUPER                a supervolcano
#
#                                                title product_metadata
# 0         Will Elon Musk visit Mars in his lifetime?              NaN
# 1                         Who will the next Pope be?              NaN
# 2  Will the world pass 2 degrees Celsius over pre...              NaN
# 3  Will a human land on Mars before California st...              NaN
# 4             Will a supervolcano erupt before 2050?              NaN

# %%
display(events_df.columns)
# Out:
# Index(['available_on_brokers', 'category', 'collateral_return_type',
#        'event_ticker', 'last_updated_ts', 'mutually_exclusive',
#        'series_ticker', 'strike_period', 'sub_title', 'title',
#        'product_metadata'],
#       dtype='str')

# %%
display(events_df.describe().transpose())
# Out:
#                        count unique                                    top  \
# available_on_brokers     100      2                                   True
# category                 100     12                          Entertainment
# collateral_return_type   100      3
# event_ticker             100    100                          KXELONMARS-99
# last_updated_ts          100      6            2026-02-26T08:50:31.901806Z
# mutually_exclusive       100      2                                  False
# series_ticker            100     92                       KXPERFORMROLE007
# strike_period            100      1
# sub_title                100     46                            Before 2030
# title                    100     97             Who will the next Pope be?
# product_metadata           4      2  {'competition': 'Pro Basketball (M)'}
#
#                        freq
# available_on_brokers     61
# category                 25
# collateral_return_type   76
# event_ticker              1
# last_updated_ts          95
# mutually_exclusive       78
# series_ticker             6
# strike_period           100
# sub_title                28
# title                     3
# product_metadata          3

# %%
display(events_df['category'].value_counts())
# Out:
# category
# Entertainment             25
# Politics                  22
# Climate and Weather        9
# Science and Technology     8
# Economics                  7
# World                      6
# Sports                     6
# Companies                  5
# Financials                 4
# Social                     3
# Elections                  3
# Health                     2
# Name: count, dtype: int64
